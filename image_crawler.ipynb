# %%
! pip install selenium

# %%
# 문상훈, 김원훈, 조진세, 오킹, 곽튜브, 레오제이, 민수(피식대학), 용준(피식대학), 덱스

# %%
from icrawler.builtin import GoogleImageCrawler
name_list = ['솔로지옥 덱스', '문상훈', '숏박스 김원훈', '조진세', '오킹', '곽튜브', '레오제이', '피식대학 민수', '피식대학 용주']

for name in name_list:
    google_crawler = GoogleImageCrawler(storage={'root_dir': name})
    google_crawler.crawl(keyword=name, max_num=200)
# Out:
# 2023-03-10 13:30:17,094 - INFO - icrawler.crawler - start crawling...
# 2023-03-10 13:30:17,096 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-03-10 13:30:17,098 - INFO - feeder - thread feeder-001 exit
# 2023-03-10 13:30:17,115 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-03-10 13:30:17,120 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-03-10 13:30:17,953 - INFO - parser - parsing result page https://www.google.com/search?q=%EC%86%94%EB%A1%9C%EC%A7%80%EC%98%A5+%EB%8D%B1%EC%8A%A4&ijn=0&start=0&tbs=&tbm=isch
# 2023-03-10 13:30:18,208 - ERROR - downloader - Response status code 404, file https://mblogthumb-phinf.pstatic.net/MjAyMjEyMjJfOTQg/MDAxNjcxNzE2MDY2NTE4.vTcthtv7K1sWYAvtMOSddFhdUi0StcycCUPlA4yo3vAg.g7tYwHpdbZT3-t88xiCeCdNA9J9F9pQSFqJ2ngy8gxQg.PNG.dlditgh999/%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7_2022-12-22_%EC%98%A4%ED%9B%84_10.33.11.png
# 2023-03-10 13:30:18,212 - INFO - downloader - skip downloading file 000001.jpg
# ...

# %%
# 추가 크롤링

# %%
    google_crawler = GoogleImageCrawler(storage={'root_dir': '숏박스 김원훈'})
    google_crawler.crawl(keyword='김원훈', max_num=200)
# Out:
# 2023-03-10 15:31:28,044 - INFO - icrawler.crawler - start crawling...
# 2023-03-10 15:31:28,045 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-03-10 15:31:28,048 - INFO - feeder - thread feeder-001 exit
# 2023-03-10 15:31:28,052 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-03-10 15:31:28,056 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-03-10 15:31:29,028 - INFO - parser - parsing result page https://www.google.com/search?q=%EA%B9%80%EC%9B%90%ED%9B%88&ijn=0&start=0&tbs=&tbm=isch
# 2023-03-10 15:31:29,133 - INFO - downloader - skip downloading file 000001.jpg
# 2023-03-10 15:31:29,707 - INFO - downloader - image #2	https://images.khan.co.kr/article/2022/08/08/news-p.v1.20220808.64b960d24be44d9eb019403bae224541_P1.png
# 2023-03-10 15:31:29,716 - INFO - downloader - skip downloading file 000003.jpg
# 2023-03-10 15:31:29,751 - INFO - downloader - downloader-001 is waiting for new download tasks
# ...

# %%
google_crawler = GoogleImageCrawler(storage={'root_dir': '피식대학 용주'})
google_crawler.crawl(keyword='피식대학 용주', max_num=200)
# Out:
# 2023-03-10 15:44:04,555 - INFO - icrawler.crawler - start crawling...
# 2023-03-10 15:44:04,557 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-03-10 15:44:04,559 - INFO - feeder - thread feeder-001 exit
# 2023-03-10 15:44:04,562 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-03-10 15:44:04,565 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-03-10 15:44:05,666 - INFO - parser - parsing result page https://www.google.com/search?q=%ED%94%BC%EC%8B%9D%EB%8C%80%ED%95%99+%EC%9A%A9%EC%A3%BC&ijn=0&start=0&tbs=&tbm=isch
# 2023-03-10 15:44:06,126 - INFO - downloader - downloader-001 is waiting for new download tasks
# 2023-03-10 15:44:07,602 - ERROR - downloader - Response status code 500, file https://images.sbs.com.au/dims4/default/f2635c0/2147483647/strip/true/crop/1440x810+0+76/resize/1280x720!/quality/90/?url\u003dhttp%3A%2F%2Fsbs-au-brightspot.s3.amazonaws.com%2Fdrupal%2Fyourlanguage%2Fpublic%2Fpodcast_images%2F_hyeonjae_sajin.jpg
# ...

# %%
google_crawler = GoogleImageCrawler(storage={'root_dir': '아옳이'})
google_crawler.crawl(keyword='아옳이', max_num=200)
# Out:
# 2023-03-10 15:44:56,325 - INFO - icrawler.crawler - start crawling...
# 2023-03-10 15:44:56,327 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-03-10 15:44:56,328 - INFO - feeder - thread feeder-001 exit
# 2023-03-10 15:44:56,332 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-03-10 15:44:56,335 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-03-10 15:44:57,219 - INFO - parser - parsing result page https://www.google.com/search?q=%EC%95%84%EC%98%B3%EC%9D%B4&ijn=0&start=0&tbs=&tbm=isch
# 2023-03-10 15:44:57,450 - INFO - downloader - image #1	https://thumb.mt.co.kr/06/2023/01/2023011119150638051_1.jpg
# 2023-03-10 15:44:57,558 - INFO - downloader - image #2	https://pds.joongang.co.kr/news/component/htmlphoto_mmdata/202301/20/b223cfe7-1b50-4c94-be73-ee55313aaa2d.jpg
# 2023-03-10 15:44:57,684 - INFO - downloader - image #3	https://img.sbs.co.kr/newsnet/etv/upload/2023/01/18/30000819204.jpg
# ...

# %%
google_crawler = GoogleImageCrawler(storage={'root_dir': '미미미누'})
google_crawler.crawl(keyword='미미미누', max_num=200)
# Out:
# 2023-03-10 15:45:22,625 - INFO - icrawler.crawler - start crawling...
# 2023-03-10 15:45:22,627 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-03-10 15:45:22,629 - INFO - feeder - thread feeder-001 exit
# 2023-03-10 15:45:22,633 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-03-10 15:45:22,635 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-03-10 15:45:23,631 - INFO - parser - parsing result page https://www.google.com/search?q=%EB%AF%B8%EB%AF%B8%EB%AF%B8%EB%88%84&ijn=0&start=0&tbs=&tbm=isch
# 2023-03-10 15:45:23,860 - INFO - downloader - image #1	https://news.einfomax.co.kr/news/photo/202209/4233251_124507_81.jpg
# 2023-03-10 15:45:24,023 - INFO - downloader - image #2	https://thumb.mt.co.kr/06/2019/01/2019011616064330009_8.jpg
# 2023-03-10 15:45:24,376 - INFO - downloader - image #3	https://i.ytimg.com/vi/eZuGCJIoQQk/maxresdefault.jpg
# ...

# %%
google_crawler = GoogleImageCrawler(storage={'root_dir': '덱스'})
google_crawler.crawl(keyword='덱스', max_num=200)
# Out:
# 2023-03-10 17:02:52,680 - INFO - icrawler.crawler - start crawling...
# 2023-03-10 17:02:52,681 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-03-10 17:02:52,684 - INFO - feeder - thread feeder-001 exit
# 2023-03-10 17:02:52,688 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-03-10 17:02:52,694 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-03-10 17:02:53,466 - INFO - parser - parsing result page https://www.google.com/search?q=%EB%8D%B1%EC%8A%A4&ijn=0&start=0&tbs=&tbm=isch
# 2023-03-10 17:02:53,544 - INFO - downloader - skip downloading file 000001.jpg
# 2023-03-10 17:02:53,547 - INFO - downloader - skip downloading file 000002.png
# 2023-03-10 17:02:53,549 - INFO - downloader - skip downloading file 000003.jpg
# 2023-03-10 17:02:53,551 - INFO - downloader - skip downloading file 000004.jpg
# 2023-03-10 17:02:53,552 - INFO - downloader - skip downloading file 000005.jpg
# ...
